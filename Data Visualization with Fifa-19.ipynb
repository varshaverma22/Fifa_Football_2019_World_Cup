# %% [markdown]
# ## Data Set: fifa_eda
# ## Data Visualization Project for analysis of Fifa Football 2019 world cup Dataset.
# ## Agenda:
# ## Perform EDA and Plot Histrogram, Scatter Plot, Bar Chart, Pie Chart, Heat Map, Pair Chart.

# %%
# import pandas, numpy and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the data 
df=pd.read_csv('C:/Users/Lenovo/Desktop/Semester- III/ML Data Set/fifa_eda.csv')
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.shape   # It provide the shape of the data
# Out:
# (18207, 18)

# %%
# Histogram
# It plot the Frequency 
# We plot 1-D columns
# histrogram are appoximztions to distribute generated through selecting values based og range range and puuting
# each set of values in a bin or bucket

# %%
plt.hist(df['Overall']) # Overall is the column of the data
# Maximum lie beyween 60 to 70 bin
# Out:
# (array([ 192.,  998., 2363., 4727., 4289., 3570., 1513.,  445.,   96.,
#           14.]),
#  array([46. , 50.8, 55.6, 60.4, 65.2, 70. , 74.8, 79.6, 84.4, 89.2, 94. ]),
#  <BarContainer object of 10 artists>)

# %%
# We can genrate a histrogram for any of the numerical columns by calling the hist() method
# specify number of bins= 10 

plt.hist(df['Overall'], edgecolor='pink', bins=10) # Create Histrogram
plt.xlabel('Overall')  # Label X-axis
plt.ylabel('Frequency') # Label Y-axis
plt.title('Histrogram of Overall Player Rating in Fifa-19') # It provide the Title of the graph
plt.show()  # This is Display graph

# %%
# We can genrate a histrogram for any of the numerical columns by calling hist() mathod
# objectt and passing in the selected column in the data frame
# We create Histrogram Program for the Overall columns, which cor
# arange(min, max)
width=10
plt.hist(df['Overall'],edgecolor='orange', bins=np.arange(min(df['Overall']),max(df['Overall'])+width,width))
plt.xlabel('Overall')  # Label X-axis
plt.ylabel('Frequency') # Label Y-axis
plt.title('Histrogram of Overall Player Rating in Fifa-19') # Title
plt.show()  # Display graph

# %%
# Sturges Rule use
# Optimal number of Bins= ceil(log2(18207)+1) = ceil(log2n+1
# facecolor change the color of histogram
import matplotlib.pyplot
width=10
plt.hist(df['Overall'],edgecolor='black', facecolor='c',bins=15,range=[50,90])
plt.xlabel('Overall')  # Label X-axis
plt.ylabel('Frequency') # Label Y-axis
plt.title('Histrogram of Overall Player Rating in Fifa-19') # Title
plt.show()  # Display graph

# %%
df.dtypes   # It provide the data type
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
# Scatter Plot
# Scatter are useful data visualization tool that helps with identifying variable dependent
# We find the relation overall wage and

# %%
plt.scatter(df['Overall'],df['Wage'])  # Take columns you find the relation
plt.title('Overall vs. Wage') # it provide the title
plt.ylabel('Wage') # Label the y axis
plt.xlabel('Overall') # Label the x axis
plt.show() # Print the grph
# Slow positive relationship

# %%
# Bar Chart are another useful visualization tool for analyzing categories in data.
# We find the Most common nationalities found in our fifa-19 
# Count
# Collections group the data

# %%
from collections import Counter  # It is count the number of times Nationality
print(Counter(df["Nationality"]))# constructure
# Out:
# Counter({'England': 1662, 'Germany': 1198, 'Spain': 1072, 'Argentina': 937, 'France': 914, 'Brazil': 827, 'Italy': 702, 'Colombia': 618, 'Japan': 478, 'Netherlands': 453, 'Sweden': 397, 'China PR': 392, 'Chile': 391, 'Republic of Ireland': 368, 'Mexico': 366, 'United States': 353, 'Poland': 350, 'Norway': 341, 'Saudi Arabia': 340, 'Denmark': 336, 'Korea Republic': 335, 'Portugal': 322, 'Turkey': 303, 'Austria': 298, 'Scotland': 286, 'Belgium': 260, 'Australia': 236, 'Switzerland': 220, 'Uruguay': 149, 'Senegal': 130, 'Wales': 129, 'Croatia': 126, 'Serbia': 126, 'Nigeria': 121, 'Ghana': 114, 'Greece': 102, 'Czech Republic': 100, 'Ivory Coast': 100, 'Cameroon': 90, 'Morocco': 85, 'Paraguay': 85, 'Northern Ireland': 80, 'Russia': 79, 'Ukraine': 73, 'South Africa': 71, 'Finland': 67, 'Venezuela': 67, 'Canada': 64, 'Bosnia Herzegovina': 61, 'Algeria': 60, 'Slovenia': 55, 'Slovakia': 54, 'Romania': 54, 'DR Congo': 52, 'Iceland': 47, 'New Zealand': 44, 'Ecuador': 43, 'Mali': 43, 'Albania': 
# ...

# %%
# We can filter this dictionary using the most_common method
# Let's look are the 10 most common nationality value
print(dict(Counter(df['Nationality']).most_common(10)))
# Out:
# {'England': 1662, 'Germany': 1198, 'Spain': 1072, 'Argentina': 937, 'France': 914, 'Brazil': 827, 'Italy': 702, 'Colombia': 618, 'Japan': 478, 'Netherlands': 453}

# %%
# To analyze most infrequent nationality values.
least_common= Counter(df['Nationality']).most_common()[::-1]
print(least_common[0:10])
# Out:
# [('Botswana', 1), ('Indonesia', 1), ('South Sudan', 1), ('Belize', 1), ('Malta', 1), ('Andorra', 1), ('Qatar', 1), ('Rwanda', 1), ('Jordan', 1), ('Grenada', 1)]

# %%
print(least_common[0:30]) # it provide the least common naltionality
# Out:
# [('Botswana', 1), ('Indonesia', 1), ('South Sudan', 1), ('Belize', 1), ('Malta', 1), ('Andorra', 1), ('Qatar', 1), ('Rwanda', 1), ('Jordan', 1), ('Grenada', 1), ('Puerto Rico', 1), ('Ethiopia', 1), ('St Lucia', 1), ('Palestine', 1), ('Lebanon', 1), ('Guam', 1), ('Liberia', 1), ('Mauritius', 1), ('Kuwait', 1), ('New Caledonia', 1), ('Fiji', 1), ('Oman', 1), ('São Tomé & Príncipe', 1), ('United Arab Emirates', 1), ('Hong Kong', 2), ('Nicaragua', 2), ('Bermuda', 2), ('Eritrea', 2), ('Philippines', 2), ('Chad', 2)]

# %%
# Finally, to genrate the bar plot of the 10 most common nationality values,
# We simple call

# %%
nationality_dict= dict(Counter(df['Nationality']).most_common(10)) # 10 most common nationality
plt.bar(nationality_dict.keys(),nationality_dict.values())
plt.xlabel("Nationality") # label the x axis
plt.ylabel("Frequency") # label the y axis
plt.title("Bar plot of ten Most Common Nationality") # It provide the Title
plt.show()

# %%
# We Rotate the Nationality
nationality_dict= dict(Counter(df['Nationality']).most_common(10)) # count the 10 most commmon nationality 
plt.bar(nationality_dict.keys(),nationality_dict.values())
plt.xlabel("Nationality")
plt.ylabel("Frequency")
plt.title("Bar plot of ten Most Common Nationality")
plt.xticks(rotation=90) # xtrick method is used to rotate the Nationality
plt.show()

# %%
# Least Common
nationality_dict= dict(least_common[0:30]) # take the least common nationality
plt.bar(nationality_dict.keys(),nationality_dict.values())
plt.xlabel("Nationality")
plt.ylabel("Frequency")
plt.title("Bar plot of ten Most Common Nationality")
plt.xticks(rotation=90) # Rotation of the graph
plt.show()

# %%
# Pie Chart are a useful way to visualize proportions in your data
# Visualize the proportions of player 
# Nationality_2 # This is the new Column
# ~ this indicate the not
# key name of country
df.loc[df.Nationality=='England','Nationality_2']="England"
df.loc[df.Nationality=='Germany','Nationality_2']="Germany"
df.loc[df.Nationality=='Spain','Nationality_2']="Spain"
df.loc[df.Nationality=='Argentina','Nationality_2']="Argentina"
df.loc[~df.Nationality.isin(['England','Germany','Spain','Argentina']),'Nationality_2']="Other"
# Create the Dictionary That contain the proportion value foreach of these:
proportion=dict(Counter(df['Nationality_2']))
for key, values in proportion.items():
    proportion[key]=(values)/len(df)*100   # It convert into percentage value
print(proportion)
# Out:
# {'Argentina': 5.146372274399956, 'Other': 73.25753830944143, 'Spain': 5.887845334212116, 'Germany': 6.579886856703466, 'England': 9.12835722524304}

# %%
df # show the data
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
# Highlight the Country through the explode.
# We have a five value so we take the 5 value
explode=(0,0,0,0,0.3) # 0,0 is centre distance form the centre
# It show the values and keys
plt.pie(proportion.values(),labels=proportion.keys(),autopct='%1.2f%%', explode=explode)
plt.figure(figsize=(10,7))
plt.show()

# %%
#.................................Seaborn...............................

# %%
# To regenrate our histrogram of the overall column
# We use the distplot method on the seaborn object:
import seaborn as sns
sns.distplot(df['Overall']) # Distplot provide the distribution plot and so as
# the naturethe plot wheather distribution is normal, right skewd and left suide
plt.xlabel('Overall')
plt.ylabel('Frequency')
plt.title("Histrogram of Overall Rating")
plt.grid()
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Seaborn also maks generating scatter plot plots straightforward
# Let's recreate the scatter plot from earlier.
sns.scatterplot(df['Overall'],df['Wage'])
plt.title('Overall vs. Wage')
plt.xlabel('Overall')
plt.ylabel('Wage')
plt.grid()
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# First you make the Heat map after it you make the scatter plot see the correlation
# Heat Map  (Important)
# It clear dependencies
# Seaborn is also for making correlation heatmap, which can be used to identify variable
# Correlation work on integer
# To genrate the correlation between a set of numerical columns
# age, Overall, Wage and Skill moves:
corr=df[['Overall','Age','Wage','Skill Moves']].corr()   # It find the corrrelation
sns.heatmap(corr,annot=True) # we set annot to true to see the correlation value
plt.title('Heatmap of Overall, Age, wage_euro, Skill Moves')
plt.show()
# Dark color show low vaue
# Take low diagonal and upper diagonal
# 1 indicate high correaltion

# %%
# Pair Plot (Important)
# This allow you to genrate a matrix of distribution and scatter plots for a set of numerical features.
# It is a quick and easy way to visualize both the distribution in numerical values and 
# relationship between variables through scatterplot
data=df[['Overall','Age','Potential']]
sns.pairplot(data) # It plot the pairplot of the data
plt.show()
